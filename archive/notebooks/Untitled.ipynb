# %%
import os
os.getcwd()
# Out:
# '/home/joshua/nfl-bdb/notebooks'

# %%
# %cd /home/joshua/nfl-bdb
# Out:
# /home/joshua/nfl-bdb
# /home/joshua/nfl-bdb/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !ls outputs
# Out:
# per_step_rmse.png

# %%
from IPython.display import Image
Image(filename="outputs/per_step_rmse.png")

# %%
from IPython.display import display
from PIL import Image as PILImage

img = PILImage.open("outputs/per_step_rmse.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2000x1000>
